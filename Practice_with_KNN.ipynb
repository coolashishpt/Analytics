# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
name = ["User ID","Game Name ","Purchase/Play","Playing Hours, 1 if Purchase", "Nothing"]
data = pd.read_csv("F:\Projects\Data_set\steam-video-games\steam-200k.csv", names= name)

data.head()
# Out:
#      User ID                  Game Name  Purchase/Play  \
# 0  151603712  The Elder Scrolls V Skyrim      purchase
# 1  151603712  The Elder Scrolls V Skyrim          play
# 2  151603712                   Fallout 4      purchase
# 3  151603712                   Fallout 4          play
# 4  151603712                       Spore      purchase
#
#    Playing Hours, 1 if Purchase  Nothing
# 0                           1.0        0
# 1                         273.0        0
# 2                           1.0        0
# 3                          87.0        0
# 4                           1.0        0

# %%
a, b = data.shape
a, b
# Out:
# (200000, 5)

# %%
data.drop(["Nothing"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#      User ID                  Game Name  Purchase/Play  \
# 0  151603712  The Elder Scrolls V Skyrim      purchase
# 1  151603712  The Elder Scrolls V Skyrim          play
# 2  151603712                   Fallout 4      purchase
# 3  151603712                   Fallout 4          play
# 4  151603712                       Spore      purchase
#
#    Playing Hours, 1 if Purchase
# 0                           1.0
# 1                         273.0
# 2                           1.0
# 3                          87.0
# 4                           1.0

# %%
X = data["Playing Hours, 1 if Purchase"]
X.head()
# Out:
# 0      1.0
# 1    273.0
# 2      1.0
# 3     87.0
# 4      1.0
# Name: Playing Hours, 1 if Purchase, dtype: float64

# %%
data.iloc[0:1, :3]
# for i in range(a):
# Out:
#      User ID                  Game Name  Purchase/Play
# 0  151603712  The Elder Scrolls V Skyrim      purchase

# %%
count = 0
Y = {}
y = []
for i in X:
    if i == 1.0:
        Y.update(data.iloc[count:count+1, :4])
        y.append(data.iloc[count:count+1, :4])
    count += 1

# %%
y
# Out:
# [     User ID                  Game Name  Purchase/Play
#  0  151603712  The Elder Scrolls V Skyrim      purchase,
#       User ID Game Name  Purchase/Play
#  2  151603712  Fallout 4      purchase,
#       User ID Game Name  Purchase/Play
#  4  151603712      Spore      purchase,
#       User ID         Game Name  Purchase/Play
#  6  151603712  Fallout New Vegas      purchase,
#       User ID     Game Name  Purchase/Play
#  8  151603712  Left 4 Dead 2      purchase,
#        User ID Game Name  Purchase/Play
#  10  151603712   HuniePop      purchase,
#        User ID     Game Name  Purchase/Play
#  12  151603712  Path of Exile      purchase,
#        User ID   Game Name  Purchase/Play
#  14  151603712  Poly Bridge      purchase,
#        User ID   Game Name  Purchase/Play
#  16  151603712  Left 4 Dead      purchase,
#        User ID       Game Name  Purchase/Play
#  18  151603712  Team Fortress 2      purchase,
#        User ID   Game Name  Purchase/Play
# ...
